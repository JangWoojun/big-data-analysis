# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
#plt.rcParams['font.family'] = 'Nanum Brush Script'
# !pip install koreanize_matplotlib

# %%
# !pip install seaborn --upgrade
sns.__version__

# %config InlineBackend.figure_format = 'retina'

# %%
import koreanize_matplotlib
plt.title('한글 폰트 확인')
plt.plot([-4,-6,1,2,0,3])
plt.show()

# %%
plt.title('한글 폰트 확인')
plt.plot([-4,-6,1,2,0,3])
plt.show()

# %%
seoul = pd.read_csv('./소상공인시장진흥공단_상가(상권)정보_서울_202312.csv',  low_memory=False)

# %%
seoul.shape
# Out:
# (489872, 39)

# %%
pd.options.display.max_columns = 39

# %%
seoul.index
# Out:
# RangeIndex(start=0, stop=489872, step=1)

# %%
seoul.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
seoul.dtypes
# Out:
# 상가업소번호        object
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드           int64
# 시도명           object
# 시군구코드          int64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드          int64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지          int64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지        float64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호          int64
# 신우편번호          int64
# 동정보          float64
# 층정보           object
# 호정보          float64
# 경도           float64
# 위도           float64
# dtype: object

# %%
#결측치확인
#seoul 데이터의 결측치 확인
#isnill() = isna()
n = seoul.isnull().sum()

# %%
n.plot.barh(figsize=(7,8))
# Out:
# <Axes: >

# %%
n.sort_values().plot.barh(figsize =(7,8))
# Out:
# <Axes: >

# %%
# !pip install missingno

# %%
import missingno as msno

# %%
msno.matrix(seoul)
# Out:
# <Axes: >

# %%
msno.heatmap(seoul)
# Out:
# <Axes: >

# %%
# dendrogrom을 이용하여 seoul 데이터의 결측치 시각화하기

msno.dendrogram(seoul)
# Out:
# <Axes: >

# %%
n[n.values !=0].sort_values(ascending = False).head(10).index
# Out:
# Index(['동정보', '호정보', '지점명', '건물부번지', '건물명', '층정보', '지번부번지', '표준산업분류코드',
#        '표준산업분류명', '건물관리번호'],
#       dtype='object')

# %%
not_use = n.sort_values(ascending = False).head(10).index

# %%
seoul.head()
# Out:
#                  상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220805430767     토끼정  NaN        I2       음식      I201
# 1  MA010120220805430763     카페숲  NaN        I2       음식      I212
# 2  MA010120220805430969     다이앤  NaN        G2       소매      G209
# 3  MA010120220805431023    숯불에닭  NaN        I2       음식      I201
# 4  MA010120220805431191  맑은에스테틱  NaN        S2    수리·개인      S208
#
#       상권업종중분류명 상권업종소분류코드     상권업종소분류명 표준산업분류코드     표준산업분류명  시도코드    시도명  \
# 0           한식    I20101       백반/한정식   I56111  한식 일반 음식점업    11  서울특별시
# 1        비알코올     I21201           카페   I56221      커피 전문점    11  서울특별시
# 2  섬유·의복·신발 소매    G20902    여성 의류 소매업   G47412  여자용 겉옷 소매업    11  서울특별시
# 3           한식    I20110  닭/오리고기 구이/찜   I56111  한식 일반 음식점업    11  서울특별시
# 4      욕탕·신체관리    S20802       마사지/안마   S96122        마사지업    11  서울특별시
#
#    시군구코드 시군구명     행정동코드  행정동명       법정동코드 법정동명                 지번코드  대지구분코드  \
# ...

# %%
print(seoul.shape)
seoul = seoul.drop(not_use, axis = 1)
print(seoul.shape)
# Out:
# (489872, 39)
# (489872, 29)

# %%
cols = seoul.columns
cols
# Out:
# Index(['상가업소번호', '상호명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명',
#        '상권업종소분류코드', '상권업종소분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드',
#        '행정동명', '법정동코드', '법정동명', '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번주소',
#        '도로명코드', '도로명', '건물본번지', '도로명주소', '구우편번호', '신우편번호', '경도', '위도'],
#       dtype='object')

# %%
cols_code = cols[cols.str.contains('코드|번호')]

# %%
cols_code = cols[cols.str.contains('코드|번호')]

# %%
seoul.drop(cols_code, axis = 1, inplace = True)

# %%
print(seoul.shape)

seoul.drop(cols_code, axis = 1, inplace = True)
# Out:
# (489872, 16)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 3
#       1 print(seoul.shape)
# ----> 3 seoul.drop(cols_code, axis = 1, inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
#행, 열 기준으로 값 가져오기
#seoul 데이터의 상호명만 상위 5개 데이터 가져오기
#열이 1개 일때는 시리즈 형태로 출력

# %%
seoul[['상호명','도로명주소']].head()

# %%
seoul.loc[0,'상호명']

# %%
seoul.iloc[0,0]

# %%
seoul.iloc[0,0]

# %%
seoul.loc[[0,1,2]]

# %%
seoul.loc[0:2]

# %%
seoul.loc[0]['상호명']

# %%
seoul.loc[0:2,['상호명','도로명주소']]
seoul.loc[[0,1,2],['상호명','도로명주소']]

# %%
seoul.iloc[0:5,0:5]

# %%
seoul.loc[0:4,'상호명':'상권업종소분류명']

# %%
seoul.loc[0:4]

# %%
seoul.iloc[0:4]

# %%
seoul.iloc[-5: , -5:]

# %%
seoul.describe()

# %%
seoul.describe(include = 'object')

# %%
seoul.describe(include = 'all')

# %%
seoul[seoul['상호명'].str.contains('CU')]

# %%
seoul['상권업종대분류명'].unique()

# %%
len(seoul['상권업종대분류명'].unique())

# %%
seoul['상권업종대분류명'].nunique()

# %%
seoul['상호명'].mode()

# %% [markdown]
# - count 결측치를 제외한 (NaN이 아닌) 값의 갯수를 계산
# - min, max 최솟값, 최댓값
# - idxmin, idxmax 최솟값, 최댓값의 인덱스 반환
# - quantile 특정 사분위수에 해당하는 값을 반환 (0~1 사이)
# - 0.25 : 1사분위 수
# - 0.5 : 2사분위수 (quantile 의 기본 값)
# - 0.75 : 3사분위수
# - sum 수치 데이터의 합계
# - mean 평균
# - median 중앙값(중간값:데이터를 한 줄로 세웠을 때 가운데 위치하는 값, 중앙값이 짝수일 때는 가운데 2개 값의 평균을 구함)
# - mad 평균값으로부터의 절대 편차(absolute deviation)의 평균
# - std, var 표준편차, 분산을 계산
# - cumsum 맨 첫 번째 성분부터 각 성분까지의 누적합을 계산 (0 번째 부터 계속 더해짐)
# - cumprod 맨 첫번째 성분부터 각 성분까지의 누적곱을 계산 (1 번째 부터 계속 곱해짐)

# %%
seoul[['위도', '경도']].describe()

# %%
seoul[['위도']].count()

# %%
seoul[['위도']].mean()

# %%
seoul[['위도']].max()

# %%
seoul[['위도']].min()

# %%
seoul[['위도']].quantile(0.25)

# %%
seoul[['위도']].var()

# %%
seoul_food = seoul[seoul['상권업종대분류명'] == '음식'].copy()

# %%
seoul_food

# %%
seoul[seoul['시군구명'] == '강남구']

# %%
(seoul['시군구명'] == '강남구') & (seoul['상권업종대분류명'] == '음식')

# %%
seoul[(seoul['상권업종대분류명'] == '음식') & (seoul['시군구명'] == '강남구')]['상권업종중분류명'].value_counts

# %%
seoul.loc[(seoul['상권업종대분류명'] == '음식') & (seoul['시군구명'] == '강남구'), '상권업종중분류명'].value_counts()

# %%
seoul_food.groupby(['시군구명', '상권업종중분류명'])['상호명'].count()

# %%
seoul_food.pivot_table(index = ['시군구명','상권업종중분류명'],
                       values = ['상호명'],
                       aggfunc = 'count')

# %%
seoul_food.pivot_table(index = ['시군구명','상권업종중분류명'],
                       values = ['상호명'],
                       aggfunc = 'count').sort_values(by = ['시군구명', '상호명'],ascending = [True, False])

# %%
food_gu = seoul_food.groupby(['시군구명', '상권업종중분류명'])['상호명'].count()
food_gu

# %%
food_gu.plot(figsize = (15,5))

# %%
#unstack 하면 멀티인덱스(시군구명, 상권업종중분류명) 형태로 되어있던 형태
#마지막 인덱스에 있던 상권업종중분류명이 컬럼으로 가게됨

# %%
food_gu.unstack()

# %%
food_gu.unstack().plot()

# %%
food_gu.unstack().plot.bar(figsize = (10,5))

# %%
food_gu.unstack()

# %%
seoul['상호명']

# %%
food_gu.unstack().loc['강남구'].plot.bar()

# %%
#seaborn으로 표현해보기
#food_gu의 인덱스를 초기화 시켜서 food에 저장하기

# %%
food = food.rename(columns = {'상호명':'상호수'})
food

# %%
# seaborn으로 그려보기
#x축 시군구명, y축 상호수, 범례 상권업종중분류명
#차트 사이즈 20,5

# %%
sns.catplot(data = food, X = '상권업종중분류명', y = '상호수', kind ='bar', aspect = 2)

# %%
sns.catplot(data = food, x='상권업종중분류명', y='상호수', kind ='bar',aspect =2, col ='시군구명', col_wrap = 2)

# %%
sns.catplot(data = food, x = '상권업종중분류명', y = '상호수' , kind = 'bar', aspect =2,col = '시군구명', col_wrap = 2, sharex = False)

# %%
sns.catplot(data = food, x = '상권업종중분류명', y = '상호수' , kind = 'bar', aspect =2,col = '시군구명', col_wrap = 2, sharex = False,  sharey = False)

# %%
sns.catplot(data = food, x = '시군구명', y = '상호수' , kind = 'bar', aspect =3,col = '상권업종중분류명', col_wrap = 2, sharex = False,palette = 'spring')

# %%
food_sort = food.sort_values(by = ['시군구명', '상호수'], ascending =[True, False])

# %%
sns.catplot(data = food_sort, x = '상권업종중분류명', y ='상호수', kind ='bar',
            aspect = 1.5, col = '시군구명', col_wrap = 2,
            sharex = False, sharey = False, palette = 'rocket')

# %%
#seborn의 카테고리형 그래프로 그리기
#food_sort 데이터를 이용하여 시군구명별 상호수 파악
#차트 넓이 3배로 늘리고 막대그래프로 표현하기
#범례를 상권업종중분류명으로 설정
#차트 색상 rocket 팔레트

# %%
plt.figure(figsize = (17,7))
sns.scatterplot(data = food, x = '시군구명', y = '상호수', hue ='상권업종중분류명', palette ='rocket')
